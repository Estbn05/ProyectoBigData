# %%
# Verificar la tabla creada
df_raw = spark.table("bigdata.default.online_retail")
df_raw.display()

# %%
#Agregar metadatos (requisito Bronze)
from pyspark.sql.functions import current_timestamp, input_file_name

df_bronze = df_raw.withColumn("load_timestamp", current_timestamp())

df_bronze.display()

# %%
#guardar como tabla bronze
df_bronze.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("bigdata.default.bronze_sales_raw")

print("✅ Tabla bronze_sales_raw creada exitosamente")
